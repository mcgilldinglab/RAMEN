# %%
from ParameterLearning import ComputeParameter

# %%
ComputeParameter( "FinalStructure10.txt", "ParameterTesting.csv", "ParameterTesting.csv" )
# Out:
# Respiratory rate (associated with BP above):.1 has failed computing
# Did or does the patient receive ventilatory support? has failed computing
# Glucose (HIGHEST value) has failed computing
# C-reactive protein (CRP): has failed computing
# If yes: (choice=Prone positioning) has failed computing
# If yes: (choice=Invasive with mechanical ventilation) has failed computing
# International Normalized Ratio (INR): has failed computing
# If yes, specify virus: (choice=Metapneumovirus) has failed computing
# Final COVID status: has failed computing
# If yes (check all that apply): (choice=Dialysis or hemofiltration) has failed computing
# Height in m: has failed computing
# Diastolic BP: has failed computing
# Acute Respiratory Distress Syndrome (ARDS)? has failed computing
# O2 saturation at room air :.1 has failed computing
# Treatments administered: (choice=Stem cells) has failed computing
# International Normalized Ratio (INR) (HIGHEST value) has failed computing
# �ge au recrutement: has failed computing
# Haemoglobin (LOWEST value) has failed computing
# Acute kidney injury? has failed computing
# Procalcitonin (PCT): has failed computing
# Obesity ? has failed computing
# If yes (check all that apply): (choice=Non-invasive support via High-flow nasal cannula (HFNC)) has failed computing
# Neutrophil (x 10^9/L): has failed computing
# Repeat Instance has failed computing
# LDH: has failed computing
# Heart rate (associated with BP above):.1 has failed computing
# Ventilatory support: has failed computing
# (choice=lesser than).1 has failed computing
# If yes: (choice=Vasopressor/inotropic support) has failed computing
# (choice=greater than).6 has failed computing
# Creatinine: has failed computing
# If yes: (choice=Non-invasive ventilation CPAP/BPAP) has failed computing
# SpO2 (the lowest associated with the highest support): has failed computing
# Pneumothorax? has failed computing
# If yes: (choice=Oxygen therapy with cannula/mask) has failed computing
# If yes (check all that apply): (choice=Neuromuscular blocking agents) has failed computing
# How much difficulty do you have transferring from a chair to a bed? has failed computing
# If yes (check all that apply): (choice=Prone positioning) has failed computing
# If yes (check all that apply): (choice=Inhaled nitric oxide (iNO)) has failed computing
# Treatments administered: (choice=Ribavirin) has failed computing
# Asymptomatic? has failed computing
# ALT (HIGHEST value) has failed computing
# Living where? has failed computing
# Creatinine (HIGHEST value) has failed computing
# Respiratory rate (associated with BP above): has failed computing
# (choice=lesser than).5 has failed computing
# Disposition: has failed computing
# On arrival,  is the participant receiving oxygen ? has failed computing
# Systolic BP:.1 has failed computing
# If yes (check all that apply): (choice=Vasopressor/inotropic support) has failed computing
# (choice=greater than).2 has failed computing
# If yes: (choice=Neuromuscular blocking agents) has failed computing
# Treatments administered: (choice=Azithromycin (Zithromax)) has failed computing
# Headache ? has failed computing
# Hyperglycemia? has failed computing
# Neutrophils (relative value): has failed computing
# Treatments administered: (choice=Interferon beta) has failed computing
# If yes: (choice=High-flow nasal cannula (HFNC)) has failed computing
# Treatments administered: (choice=Tocilizumab (Actemra)) has failed computing
# Diastolic BP:.1 has failed computing
# Oxygen therapy has failed computing
# Lymphocyte (relative value): has failed computing
# Total bilirubin (HIGHEST value) has failed computing
# Albumin: has failed computing
# At the time of collection, SpO2 on oxygen: has failed computing
# Sodium Na+ (HIGHEST value) has failed computing
# Total WBC count: has failed computing
# On arrival, SpO2 on oxygen: has failed computing
# Lymphocyte (relative value) (LOWEST value) has failed computing
# If yes (check all that apply): (choice=Invasive support with mechanical ventilation) has failed computing
# If a screening test for SARS-CoV-2 by PCR was performed, what is the most severe severity level (according to WHO) achieved? has failed computing
# How would you rate your current level of functioning? See options above. has failed computing
# APTT (activated partial thromboplastin time) (HIGHEST value) has failed computing
# AVPU Scale: has failed computing
# Treatments administered: (choice=Other antibiotic (specify)) has failed computing
# Heart rate (associated with BP above): has failed computing
# Emergency visit only? has failed computing
# Albumin (LOWEST value) has failed computing
# Urea (HIGHEST value) has failed computing
# Skin rash ? has failed computing
# Usual activities, including work, study, housework, family or leisure activities: has failed computing
# Positive bacterial culture documented during hospitalization? has failed computing
# Mobility has failed computing
# Bacterial pneumonia? has failed computing
# O2 saturation at room air : has failed computing
# If yes: (choice=High-frequency oscillatory ventilation) has failed computing
# Status COVID: has failed computing
# Vital status at discharge: has failed computing
# Systolic BP: has failed computing
# Number of other comorbidities:  has failed computing
# Treatments administered: (choice=Other antiviral (specify)) has failed computing
# If yes (check all that apply): (choice=Non-invasive ventilation CPAP/BPAP) has failed computing
# ICU admission? has failed computing
# Platelet (LOWEST value) has failed computing
# Level of care (final): has failed computing
# Other COVID-19 treatment(s) has failed computing
# Treatments administered: (choice=Interferon alpha) has failed computing
# If yes (check all that apply): (choice=Tracheostomy) has failed computing
# Ability to self-care at discharge versus pre-COVID: has failed computing
# If yes: (choice=Dialysis or hemofiltration) has failed computing
# Rhabdomyolysis or myositis? has failed computing
# Pulmonary embolism (PE)? has failed computing
# If yes (check all that apply): (choice=Non-invasive cannula/mask support) has failed computing
# If yes (check all that apply): (choice=Blood transfusion) has failed computing
# Duration of hospitalization: has failed computing
# Glasgow Coma Scale (GCS) - lowest value: has failed computing
# BMI: has failed computing
# Sodium Na+: has failed computing
# C-reactive protein (CRP) (HIGHEST value) has failed computing
# Adjunctive therapy during hospitalization has failed computing
# If yes, specify virus: (choice=Adenovirus) has failed computing
# If yes, specify virus: (choice=Parainfluenza) has failed computing
# Neutrophil (relative value) (HIGHEST value) has failed computing
# Treatments administered: (choice=Systematic corticosteroid) has failed computing
# Glucose: has failed computing
# D-Dimer (HIGHEST value) has failed computing
# At the time of collection, is the participant receiving oxygen ? has failed computing
# Specify other antibiotic. has failed computing
# Treatments administered: (choice=Antifungal) has failed computing
# Haemoglobin : has failed computing
# Bacteremia? has failed computing
# Anticoagulants? has failed computing
# Treatments administered: (choice=Chloroquine (Aralen)) has failed computing
# Number of other complications:  has failed computing
# Weight in kg: has failed computing
