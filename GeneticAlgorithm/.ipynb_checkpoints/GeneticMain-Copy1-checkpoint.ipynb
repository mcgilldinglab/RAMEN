# %%
from GeneticAlgorithmLauncher import StructuredLearningRun

# %%
#StructuredLearningRun( "LearningData.csv", "notcorrected001v11.txt", 10, 1, 100, 10, 3, 0.3, "FinalStructure03.txt" )
#StructuredLearningRun( "LearningData.csv", "CandidatesFile2.txt", 10, 0.25, 100, 10, 10, 1, "NewFinalStructureTEST18.txt", 100, "", 0.10, 0.255 )
#CandidatesSaveFile
#StructuredLearningRun( "CsvData/long_covid_out3.csv", "SignificantEdges/long_cov_sig.txt", 10, 0.25, 100, 10, 10, 1, "Results/long_out101.txt", 200, "", 0.1, 0.02 )
#StructuredLearningRun( "CsvData/long_cov_out.csv", "SignificantEdges/long_cov_sig.txt", 10, 0.1, 100, 10, 10, 1, "Results/long_out010051.txt", 200, "", 0.1, 0.051 )

#StructuredLearningRun( "CsvData/sev_in.csv", "SignificantEdges/sev_sig.txt", 10, 0.01, 100, 10, 10, 1, "Results/sev_out.txt", 200, "", 0, 0.2 )

StructuredLearningRun( "CsvData/sev_in.csv", "SignificantEdges/sev_sig.txt", 10, 0.01, 100, 10, 10, 1, "Results/sev001.txt", 30, "", 0.01, 0 )
# Out:
# 287
# initializing scorer
# done initializing scorer
# making candidates
# Finished making candidates in: 7.766210005996982
# starting Genetic Algorithm
# -194.78027999134588
# generation: 0 best: -193.54859841328928
# generation: 1 best: -193.065071213962
# Process Process-133:
# Process Process-117:
# Process Process-125:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1540541/1351942793.py in <module>
#       7 #StructuredLearningRun( "CsvData/sev_in.csv", "SignificantEdges/sev_sig.txt", 10, 0.01, 100, 10, 10, 1, "Results/sev_out.txt", 200, "", 0, 0.2 )
#       8
# ----> 9 StructuredLearningRun( "CsvData/sev_in.csv", "SignificantEdges/sev_sig.txt", 10, 0.01, 100, 10, 10, 1, "Results/sev001.txt", 100, "", 0.01, 0 )
#
# /mnt/data/yiwei/GeneticAlgorithm/GeneticAlgorithmLauncher.py in StructuredLearningRun(scoring_dataframe_file, significant_edges_file, num_candidates, end_thresh, mutate_num, best_cand_num, bad_reprod_accept, regular_factor, end_file_name, hard_stop_counter, pickle_save_file, alpha, beta)
#      24     print( "Finished making candidates in", end = ": ")
#      25     print( endtime-startime )
# ---> 26     children = GeneticRun( candidates, end_thresh, mutate_num, best_cand_num, bad_reprod_accept, scorer, hard_stop_counter )
#      27
#      28     outfile = open("CandidatesSaveFile" + "0" + str(alpha)[2:],'wb')
#
# /mnt/data/yiwei/GeneticAlgorithm/GeneticAlgorithm.py in GeneticRun(start_parents, end_thresh, mutate_numb, best_cand_num, bad_reprod_accept, scorer, hard_stop_counter)
#      26     counter = 0
#      27     while(  counter < hard_stop_counter ):
# ---> 28         next_Gen = MakeNextGen( lastGen, mutate_numb, best_cand_num, scorer )
#      29         best = next_Gen[ 0 ].score
#      30         LogScoreAndEdges( scoreLog, next_Gen[ 0 ].matrix, next_Gen[ 0 ].score )
#
# /mnt/data/yiwei/GeneticAlgorithm/GeneticAlgorithm.py in MakeNextGen(matrixListe, mutate_numb, numb_to_keep, scorer)
#      87     AddCrossOverChildren( allChildren, scorer )
#      88
# ---> 89     mutationList = GetMutateChildren( allChildren, mutate_numb, numb_to_keep, scorer )
#      90     allChildren += mutationList.ConvertListToMatrixObj()
#      91     return GetBestChildren( allChildren, numb_to_keep )
#
# /mnt/data/yiwei/GeneticAlgorithm/GeneticAlgorithm.py in GetMutateChildren(allChildren, mutate_numb, numb_to_keep, scorer)
#     103
#     104     for proc in jobs:
# --> 105         proc.join()
#     106     for key in return_dict:
#     107         mutationList.insertListe( return_dict[ key ] )
#
# /usr/lib/python3.8/multiprocessing/process.py in join(self, timeout)
#     147         assert self._parent_pid == os.getpid(), 'can only join a child process'
#     148         assert self._popen is not None, 'can only join a started process'
# --> 149         res = self._popen.wait(timeout)
#     150         if res is not None:
#     151             _children.discard(self)
#
# /usr/lib/python3.8/multiprocessing/popen_fork.py in wait(self, timeout)
#      45                     return None
#      46             # This shouldn't block if wait() returned successfully.
# ---> 47             return self.poll(os.WNOHANG if timeout == 0.0 else 0)
#      48         return self.returncode
#      49
#
# /usr/lib/python3.8/multiprocessing/popen_fork.py in poll(self, flag)
#      25         if self.returncode is None:
#      26             try:
# ---> 27                 pid, sts = os.waitpid(self.pid, flag)
#      28             except OSError as e:
#      29                 # Child process not yet created. See #1731717
#
# KeyboardInterrupt:
# Process Process-124:
# Process Process-132:
# Process Process-129:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Process Process-118:
# Traceback (most recent call last):
# Process Process-121:
# Process Process-131:
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process Process-116:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Process Process-120:
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process Process-122:
#   File "/mnt/data/yiwei/GeneticAlgorithm/GeneticAlgorithm.py", line 138, in MutateWorker
#     mutation = MutateMatrix( child, scorer )
# Process Process-126:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process Process-115:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/mnt/data/yiwei/GeneticAlgorithm/GeneticAlgorithm.py", line 138, in MutateWorker
#     mutation = MutateMatrix( child, scorer )
# Process Process-130:
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 7, in MutateMatrix
#     return MutateMatrixOneEdge( matrix, scorer )
# Process Process-128:
# Process Process-127:
# Process Process-123:
# Traceback (most recent call last):
# Process Process-119:
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/mnt/data/yiwei/GeneticAlgorithm/GeneticAlgorithm.py", line 138, in MutateWorker
#     mutation = MutateMatrix( child, scorer )
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/mnt/data/yiwei/GeneticAlgorithm/GeneticAlgorithm.py", line 138, in MutateWorker
#     mutation = MutateMatrix( child, scorer )
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 7, in MutateMatrix
#     return MutateMatrixOneEdge( matrix, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 40, in MutateMatrixOneEdge
#     mutation = MutationMake( matrixObj, changeList, affected_nodes, scorer )
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/mnt/data/yiwei/GeneticAlgorithm/GeneticAlgorithm.py", line 138, in MutateWorker
#     mutation = MutateMatrix( child, scorer )
# Traceback (most recent call last):
#   File "/mnt/data/yiwei/GeneticAlgorithm/GeneticAlgorithm.py", line 138, in MutateWorker
#     mutation = MutateMatrix( child, scorer )
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 9, in MutateMatrix
#     return MutateMatrixTwoEdges( matrix, scorer )
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 7, in MutateMatrix
#     return MutateMatrixOneEdge( matrix, scorer )
# Traceback (most recent call last):
# Process Process-134:
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/mnt/data/yiwei/GeneticAlgorithm/Mutation.py", line 5, in MutationMake
#     mutation = Mutation( matrixObj, changeList, affected_nodes, scorer )
# Traceback (most recent call last):
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 40, in MutateMatrixOneEdge
#     mutation = MutationMake( matrixObj, changeList, affected_nodes, scorer )
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 9, in MutateMatrix
#     return MutateMatrixTwoEdges( matrix, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 7, in MutateMatrix
#     return MutateMatrixOneEdge( matrix, scorer )
# Traceback (most recent call last):
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 106, in MutateMatrixTwoEdges
#     mutation = FlipTwoEdges( matrixObj, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/GeneticAlgorithm.py", line 138, in MutateWorker
#     mutation = MutateMatrix( child, scorer )
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 40, in MutateMatrixOneEdge
#     mutation = MutationMake( matrixObj, changeList, affected_nodes, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/GeneticAlgorithm.py", line 138, in MutateWorker
#     mutation = MutateMatrix( child, scorer )
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/mnt/data/yiwei/GeneticAlgorithm/Mutation.py", line 25, in __init__
#     oldScore = scorer.Score( self.matrix, nodes_to_score = affected_nodes )
#   File "/mnt/data/yiwei/GeneticAlgorithm/GeneticAlgorithm.py", line 138, in MutateWorker
#     mutation = MutateMatrix( child, scorer )
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/mnt/data/yiwei/GeneticAlgorithm/Mutation.py", line 5, in MutationMake
#     mutation = Mutation( matrixObj, changeList, affected_nodes, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/GeneticAlgorithm.py", line 138, in MutateWorker
#     mutation = MutateMatrix( child, scorer )
# Traceback (most recent call last):
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 102, in MutateMatrixTwoEdges
#     mutation = RemoveTwoEdges( matrixObj, scorer )
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 9, in MutateMatrix
#     return MutateMatrixTwoEdges( matrix, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 40, in MutateMatrixOneEdge
#     mutation = MutationMake( matrixObj, changeList, affected_nodes, scorer )
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 88, in FlipTwoEdges
#     mutation = MutationMake( matrixObj, changeList, affected_nodes, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 7, in MutateMatrix
#     return MutateMatrixOneEdge( matrix, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/GeneticAlgorithm.py", line 138, in MutateWorker
#     mutation = MutateMatrix( child, scorer )
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/mnt/data/yiwei/GeneticAlgorithm/Mutation.py", line 5, in MutationMake
#     mutation = Mutation( matrixObj, changeList, affected_nodes, scorer )
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 9, in MutateMatrix
#     return MutateMatrixTwoEdges( matrix, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Scorer.py", line 48, in Score
#     score = ScoreSelectNodesFromAdjMatrix( matrix, nodes_to_score, self.regular_factor, self.columns, self.alpha )
#   File "/mnt/data/yiwei/GeneticAlgorithm/GeneticAlgorithm.py", line 138, in MutateWorker
#     mutation = MutateMatrix( child, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/GeneticAlgorithm.py", line 138, in MutateWorker
#     mutation = MutateMatrix( child, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Mutation.py", line 25, in __init__
#     oldScore = scorer.Score( self.matrix, nodes_to_score = affected_nodes )
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 55, in RemoveTwoEdges
#     mutation = MutationMake( matrixObj, changeList, affected_nodes, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 7, in MutateMatrix
#     return MutateMatrixOneEdge( matrix, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 106, in MutateMatrixTwoEdges
#     mutation = FlipTwoEdges( matrixObj, scorer )
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/mnt/data/yiwei/GeneticAlgorithm/GeneticAlgorithm.py", line 138, in MutateWorker
#     mutation = MutateMatrix( child, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Mutation.py", line 5, in MutationMake
#     mutation = Mutation( matrixObj, changeList, affected_nodes, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 9, in MutateMatrix
#     return MutateMatrixTwoEdges( matrix, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Mutation.py", line 5, in MutationMake
#     mutation = Mutation( matrixObj, changeList, affected_nodes, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 40, in MutateMatrixOneEdge
#     mutation = MutationMake( matrixObj, changeList, affected_nodes, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/GeneticAlgorithm.py", line 138, in MutateWorker
#     mutation = MutateMatrix( child, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/GeneticAlgorithm.py", line 138, in MutateWorker
#     mutation = MutateMatrix( child, scorer )
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/mnt/data/yiwei/GeneticAlgorithm/GeneticAlgorithm.py", line 138, in MutateWorker
#     mutation = MutateMatrix( child, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Mutation.py", line 25, in __init__
#     oldScore = scorer.Score( self.matrix, nodes_to_score = affected_nodes )
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 106, in MutateMatrixTwoEdges
#     mutation = FlipTwoEdges( matrixObj, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 7, in MutateMatrix
#     return MutateMatrixOneEdge( matrix, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Scorer.py", line 70, in ScoreSelectNodesFromAdjMatrix
#     score = - ( drv.entropy_joint( parents_and_node, fill_value = -999 ) - drv.entropy_joint( parents, fill_value = -999 ) )
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 7, in MutateMatrix
#     return MutateMatrixOneEdge( matrix, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Scorer.py", line 48, in Score
#     score = ScoreSelectNodesFromAdjMatrix( matrix, nodes_to_score, self.regular_factor, self.columns, self.alpha )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Mutation.py", line 5, in MutationMake
#     mutation = Mutation( matrixObj, changeList, affected_nodes, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/GeneticAlgorithm.py", line 138, in MutateWorker
#     mutation = MutateMatrix( child, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 40, in MutateMatrixOneEdge
#     mutation = MutationMake( matrixObj, changeList, affected_nodes, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 88, in FlipTwoEdges
#     mutation = MutationMake( matrixObj, changeList, affected_nodes, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 9, in MutateMatrix
#     return MutateMatrixTwoEdges( matrix, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Mutation.py", line 25, in __init__
#     oldScore = scorer.Score( self.matrix, nodes_to_score = affected_nodes )
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 106, in MutateMatrixTwoEdges
#     mutation = FlipTwoEdges( matrixObj, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Mutation.py", line 30, in __init__
#     newScore = scorer.Score( self.matrix, nodes_to_score = affected_nodes )
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 7, in MutateMatrix
#     return MutateMatrixOneEdge( matrix, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Mutation.py", line 5, in MutationMake
#     mutation = Mutation( matrixObj, changeList, affected_nodes, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 7, in MutateMatrix
#     return MutateMatrixOneEdge( matrix, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/GeneticAlgorithm.py", line 138, in MutateWorker
#     mutation = MutateMatrix( child, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 7, in MutateMatrix
#     return MutateMatrixOneEdge( matrix, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Scorer.py", line 48, in Score
#     score = ScoreSelectNodesFromAdjMatrix( matrix, nodes_to_score, self.regular_factor, self.columns, self.alpha )
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 88, in FlipTwoEdges
#     mutation = MutationMake( matrixObj, changeList, affected_nodes, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 40, in MutateMatrixOneEdge
#     mutation = MutationMake( matrixObj, changeList, affected_nodes, scorer )
#   File "/home/yiwei/.local/lib/python3.8/site-packages/pyitlib/discrete_random_variable.py", line 3685, in entropy_joint
#     X = X[:, X[i].argsort(kind='mergesort')]
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 40, in MutateMatrixOneEdge
#     mutation = MutationMake( matrixObj, changeList, affected_nodes, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Mutation.py", line 25, in __init__
#     oldScore = scorer.Score( self.matrix, nodes_to_score = affected_nodes )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Scorer.py", line 70, in ScoreSelectNodesFromAdjMatrix
#     score = - ( drv.entropy_joint( parents_and_node, fill_value = -999 ) - drv.entropy_joint( parents, fill_value = -999 ) )
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 9, in MutateMatrix
#     return MutateMatrixTwoEdges( matrix, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Mutation.py", line 5, in MutationMake
#     mutation = Mutation( matrixObj, changeList, affected_nodes, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Mutation.py", line 5, in MutationMake
#     mutation = Mutation( matrixObj, changeList, affected_nodes, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 106, in MutateMatrixTwoEdges
#     mutation = FlipTwoEdges( matrixObj, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Scorer.py", line 48, in Score
#     score = ScoreSelectNodesFromAdjMatrix( matrix, nodes_to_score, self.regular_factor, self.columns, self.alpha )
#   File "/mnt/data/yiwei/GeneticAlgorithm/GeneticAlgorithm.py", line 138, in MutateWorker
#     mutation = MutateMatrix( child, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 88, in FlipTwoEdges
#     mutation = MutationMake( matrixObj, changeList, affected_nodes, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Scorer.py", line 48, in Score
#     score = ScoreSelectNodesFromAdjMatrix( matrix, nodes_to_score, self.regular_factor, self.columns, self.alpha )
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 40, in MutateMatrixOneEdge
#     mutation = MutationMake( matrixObj, changeList, affected_nodes, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Mutation.py", line 25, in __init__
#     oldScore = scorer.Score( self.matrix, nodes_to_score = affected_nodes )
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 7, in MutateMatrix
#     return MutateMatrixOneEdge( matrix, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 40, in MutateMatrixOneEdge
#     mutation = MutationMake( matrixObj, changeList, affected_nodes, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Scorer.py", line 70, in ScoreSelectNodesFromAdjMatrix
#     score = - ( drv.entropy_joint( parents_and_node, fill_value = -999 ) - drv.entropy_joint( parents, fill_value = -999 ) )
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 40, in MutateMatrixOneEdge
#     mutation = MutationMake( matrixObj, changeList, affected_nodes, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Mutation.py", line 5, in MutationMake
#     mutation = Mutation( matrixObj, changeList, affected_nodes, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Mutation.py", line 5, in MutationMake
#     mutation = Mutation( matrixObj, changeList, affected_nodes, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Mutation.py", line 5, in MutationMake
#     mutation = Mutation( matrixObj, changeList, affected_nodes, scorer )
# KeyboardInterrupt
#   File "/mnt/data/yiwei/GeneticAlgorithm/Scorer.py", line 48, in Score
#     score = ScoreSelectNodesFromAdjMatrix( matrix, nodes_to_score, self.regular_factor, self.columns, self.alpha )
#   File "/home/yiwei/.local/lib/python3.8/site-packages/pyitlib/discrete_random_variable.py", line 3652, in entropy_joint
#     Alphabet_X, fill_value_Alphabet_X = _autocreate_alphabet(X,
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 106, in MutateMatrixTwoEdges
#     mutation = FlipTwoEdges( matrixObj, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Mutation.py", line 30, in __init__
#     newScore = scorer.Score( self.matrix, nodes_to_score = affected_nodes )
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 88, in FlipTwoEdges
#     mutation = MutationMake( matrixObj, changeList, affected_nodes, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Mutation.py", line 30, in __init__
#     newScore = scorer.Score( self.matrix, nodes_to_score = affected_nodes )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Mutation.py", line 5, in MutationMake
#     mutation = Mutation( matrixObj, changeList, affected_nodes, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 7, in MutateMatrix
#     return MutateMatrixOneEdge( matrix, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Scorer.py", line 70, in ScoreSelectNodesFromAdjMatrix
#     score = - ( drv.entropy_joint( parents_and_node, fill_value = -999 ) - drv.entropy_joint( parents, fill_value = -999 ) )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Scorer.py", line 70, in ScoreSelectNodesFromAdjMatrix
#     score = - ( drv.entropy_joint( parents_and_node, fill_value = -999 ) - drv.entropy_joint( parents, fill_value = -999 ) )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Scorer.py", line 48, in Score
#     score = ScoreSelectNodesFromAdjMatrix( matrix, nodes_to_score, self.regular_factor, self.columns, self.alpha )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Mutation.py", line 5, in MutationMake
#     mutation = Mutation( matrixObj, changeList, affected_nodes, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Mutation.py", line 5, in MutationMake
#     mutation = Mutation( matrixObj, changeList, affected_nodes, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 40, in MutateMatrixOneEdge
#     mutation = MutationMake( matrixObj, changeList, affected_nodes, scorer )
#   File "/home/yiwei/.local/lib/python3.8/site-packages/pyitlib/discrete_random_variable.py", line 3685, in entropy_joint
#     X = X[:, X[i].argsort(kind='mergesort')]
#   File "/mnt/data/yiwei/GeneticAlgorithm/Mutation.py", line 5, in MutationMake
#     mutation = Mutation( matrixObj, changeList, affected_nodes, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Mutation.py", line 25, in __init__
#     oldScore = scorer.Score( self.matrix, nodes_to_score = affected_nodes )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Mutation.py", line 25, in __init__
#     oldScore = scorer.Score( self.matrix, nodes_to_score = affected_nodes )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Mutation.py", line 25, in __init__
#     oldScore = scorer.Score( self.matrix, nodes_to_score = affected_nodes )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Scorer.py", line 70, in ScoreSelectNodesFromAdjMatrix
#     score = - ( drv.entropy_joint( parents_and_node, fill_value = -999 ) - drv.entropy_joint( parents, fill_value = -999 ) )
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 88, in FlipTwoEdges
#     mutation = MutationMake( matrixObj, changeList, affected_nodes, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Scorer.py", line 48, in Score
#     score = ScoreSelectNodesFromAdjMatrix( matrix, nodes_to_score, self.regular_factor, self.columns, self.alpha )
#   File "/home/yiwei/.local/lib/python3.8/site-packages/pyitlib/discrete_random_variable.py", line 4397, in _autocreate_alphabet
#     Alphabet = np.apply_along_axis(lambda x: pad_with_fillvalue(np.unique(x)),
#   File "/mnt/data/yiwei/GeneticAlgorithm/Mutation.py", line 25, in __init__
#     oldScore = scorer.Score( self.matrix, nodes_to_score = affected_nodes )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Scorer.py", line 48, in Score
#     score = ScoreSelectNodesFromAdjMatrix( matrix, nodes_to_score, self.regular_factor, self.columns, self.alpha )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Mutation.py", line 5, in MutationMake
#     mutation = Mutation( matrixObj, changeList, affected_nodes, scorer )
#   File "/mnt/data/yiwei/GeneticAlgorithm/MatrixMutater.py", line 40, in MutateMatrixOneEdge
#     mutation = MutationMake( matrixObj, changeList, affected_nodes, scorer )
#   File "/home/yiwei/.local/lib/python3.8/site-packages/pyitlib/discrete_random_variable.py", line 3689, in entropy_joint
#     B = np.any(X[:, 1:] != X[:, :-1], axis=0)
#   File "/home/yiwei/.local/lib/python3.8/site-packages/pyitlib/discrete_random_variable.py", line 3685, in entropy_joint
#     X = X[:, X[i].argsort(kind='mergesort')]
#   File "/mnt/data/yiwei/GeneticAlgorithm/Mutation.py", line 25, in __init__
#     oldScore = scorer.Score( self.matrix, nodes_to_score = affected_nodes )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Mutation.py", line 30, in __init__
#     newScore = scorer.Score( self.matrix, nodes_to_score = affected_nodes )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Scorer.py", line 70, in ScoreSelectNodesFromAdjMatrix
#     score = - ( drv.entropy_joint( parents_and_node, fill_value = -999 ) - drv.entropy_joint( parents, fill_value = -999 ) )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Mutation.py", line 25, in __init__
#     oldScore = scorer.Score( self.matrix, nodes_to_score = affected_nodes )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Mutation.py", line 5, in MutationMake
#     mutation = Mutation( matrixObj, changeList, affected_nodes, scorer )
# KeyboardInterrupt
#   File "/mnt/data/yiwei/GeneticAlgorithm/Scorer.py", line 48, in Score
#     score = ScoreSelectNodesFromAdjMatrix( matrix, nodes_to_score, self.regular_factor, self.columns, self.alpha )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Scorer.py", line 48, in Score
#     score = ScoreSelectNodesFromAdjMatrix( matrix, nodes_to_score, self.regular_factor, self.columns, self.alpha )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Scorer.py", line 48, in Score
#     score = ScoreSelectNodesFromAdjMatrix( matrix, nodes_to_score, self.regular_factor, self.columns, self.alpha )
#   File "/home/yiwei/.local/lib/python3.8/site-packages/pyitlib/discrete_random_variable.py", line 3685, in entropy_joint
#     X = X[:, X[i].argsort(kind='mergesort')]
#   File "/mnt/data/yiwei/GeneticAlgorithm/Mutation.py", line 5, in MutationMake
#     mutation = Mutation( matrixObj, changeList, affected_nodes, scorer )
#   File "<__array_function__ internals>", line 180, in apply_along_axis
#   File "/mnt/data/yiwei/GeneticAlgorithm/Scorer.py", line 48, in Score
#     score = ScoreSelectNodesFromAdjMatrix( matrix, nodes_to_score, self.regular_factor, self.columns, self.alpha )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Scorer.py", line 70, in ScoreSelectNodesFromAdjMatrix
#     score = - ( drv.entropy_joint( parents_and_node, fill_value = -999 ) - drv.entropy_joint( parents, fill_value = -999 ) )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Scorer.py", line 70, in ScoreSelectNodesFromAdjMatrix
#     score = - ( drv.entropy_joint( parents_and_node, fill_value = -999 ) - drv.entropy_joint( parents, fill_value = -999 ) )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Mutation.py", line 25, in __init__
#     oldScore = scorer.Score( self.matrix, nodes_to_score = affected_nodes )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Mutation.py", line 5, in MutationMake
#     mutation = Mutation( matrixObj, changeList, affected_nodes, scorer )
# KeyboardInterrupt
#   File "<__array_function__ internals>", line 180, in any
#   File "/mnt/data/yiwei/GeneticAlgorithm/Scorer.py", line 48, in Score
#     score = ScoreSelectNodesFromAdjMatrix( matrix, nodes_to_score, self.regular_factor, self.columns, self.alpha )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Scorer.py", line 48, in Score
#     score = ScoreSelectNodesFromAdjMatrix( matrix, nodes_to_score, self.regular_factor, self.columns, self.alpha )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Scorer.py", line 48, in Score
#     score = ScoreSelectNodesFromAdjMatrix( matrix, nodes_to_score, self.regular_factor, self.columns, self.alpha )
#   File "/home/yiwei/.local/lib/python3.8/site-packages/pyitlib/discrete_random_variable.py", line 3671, in entropy_joint
#     S, fill_value = _map_observations_to_integers((X, Alphabet_X),
#   File "/mnt/data/yiwei/GeneticAlgorithm/Mutation.py", line 25, in __init__
#     oldScore = scorer.Score( self.matrix, nodes_to_score = affected_nodes )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Scorer.py", line 70, in ScoreSelectNodesFromAdjMatrix
#     score = - ( drv.entropy_joint( parents_and_node, fill_value = -999 ) - drv.entropy_joint( parents, fill_value = -999 ) )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Scorer.py", line 70, in ScoreSelectNodesFromAdjMatrix
#     score = - ( drv.entropy_joint( parents_and_node, fill_value = -999 ) - drv.entropy_joint( parents, fill_value = -999 ) )
# KeyboardInterrupt
#   File "/mnt/data/yiwei/GeneticAlgorithm/Scorer.py", line 70, in ScoreSelectNodesFromAdjMatrix
#     score = - ( drv.entropy_joint( parents_and_node, fill_value = -999 ) - drv.entropy_joint( parents, fill_value = -999 ) )
#   File "/home/yiwei/.local/lib/python3.8/site-packages/numpy/lib/shape_base.py", line 402, in apply_along_axis
#     buff[ind] = asanyarray(func1d(inarr_view[ind], *args, **kwargs))
#   File "/mnt/data/yiwei/GeneticAlgorithm/Mutation.py", line 25, in __init__
#     oldScore = scorer.Score( self.matrix, nodes_to_score = affected_nodes )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Scorer.py", line 70, in ScoreSelectNodesFromAdjMatrix
#     score = - ( drv.entropy_joint( parents_and_node, fill_value = -999 ) - drv.entropy_joint( parents, fill_value = -999 ) )
#   File "/home/yiwei/.local/lib/python3.8/site-packages/pyitlib/discrete_random_variable.py", line 3681, in entropy_joint
#     _verify_alphabet_sufficiently_large(X, Alphabet_X, fill_value)
#   File "/mnt/data/yiwei/GeneticAlgorithm/Scorer.py", line 48, in Score
#     score = ScoreSelectNodesFromAdjMatrix( matrix, nodes_to_score, self.regular_factor, self.columns, self.alpha )
#   File "/home/yiwei/.local/lib/python3.8/site-packages/pyitlib/discrete_random_variable.py", line 3685, in entropy_joint
#     X = X[:, X[i].argsort(kind='mergesort')]
#   File "/mnt/data/yiwei/GeneticAlgorithm/Mutation.py", line 25, in __init__
#     oldScore = scorer.Score( self.matrix, nodes_to_score = affected_nodes )
#   File "/mnt/data/yiwei/GeneticAlgorithm/Scorer.py", line 70, in ScoreSelectNodesFromAdjMatrix
#     score = - ( drv.entropy_joint( parents_and_node, fill_value = -999 ) - drv.entropy_joint( parents, fill_value = -999 ) )
#   File "/home/yiwei/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py", line 2395, in any
#     return _wrapreduction(a, np.logical_or, 'any', axis, None, out,
#   File "/mnt/data/yiwei/GeneticAlgorithm/Scorer.py", line 70, in ScoreSelectNodesFromAdjMatrix
#     score = - ( drv.entropy_joint( parents_and_node, fill_value = -999 ) - drv.entropy_joint( parents, fill_value = -999 ) )
#   File "/home/yiwei/.local/lib/python3.8/site-packages/pyitlib/discrete_random_variable.py", line 3671, in entropy_joint
#     S, fill_value = _map_observations_to_integers((X, Alphabet_X),
#   File "/mnt/data/yiwei/GeneticAlgorithm/Scorer.py", line 70, in ScoreSelectNodesFromAdjMatrix
#     score = - ( drv.entropy_joint( parents_and_node, fill_value = -999 ) - drv.entropy_joint( parents, fill_value = -999 ) )
#   File "/home/yiwei/.local/lib/python3.8/site-packages/pyitlib/discrete_random_variable.py", line 4685, in _map_observations_to_integers
#     L.fit(np.concatenate([A.ravel() for A in Symbol_matrices] + F))
#   File "/mnt/data/yiwei/GeneticAlgorithm/Scorer.py", line 48, in Score
#     score = ScoreSelectNodesFromAdjMatrix( matrix, nodes_to_score, self.regular_factor, self.columns, self.alpha )
#   File "/home/yiwei/.local/lib/python3.8/site-packages/pyitlib/discrete_random_variable.py", line 3685, in entropy_joint
#     X = X[:, X[i].argsort(kind='mergesort')]
#   File "/home/yiwei/.local/lib/python3.8/site-packages/pyitlib/discrete_random_variable.py", line 3685, in entropy_joint
#     X = X[:, X[i].argsort(kind='mergesort')]
#   File "/home/yiwei/.local/lib/python3.8/site-packages/pyitlib/discrete_random_variable.py", line 4397, in <lambda>
#     Alphabet = np.apply_along_axis(lambda x: pad_with_fillvalue(np.unique(x)),
#   File "/mnt/data/yiwei/GeneticAlgorithm/Scorer.py", line 48, in Score
#     score = ScoreSelectNodesFromAdjMatrix( matrix, nodes_to_score, self.regular_factor, self.columns, self.alpha )
#   File "/home/yiwei/.local/lib/python3.8/site-packages/pyitlib/discrete_random_variable.py", line 3685, in entropy_joint
#     X = X[:, X[i].argsort(kind='mergesort')]
#   File "/mnt/data/yiwei/GeneticAlgorithm/Scorer.py", line 70, in ScoreSelectNodesFromAdjMatrix
#     score = - ( drv.entropy_joint( parents_and_node, fill_value = -999 ) - drv.entropy_joint( parents, fill_value = -999 ) )
# KeyboardInterrupt
#   File "/home/yiwei/.local/lib/python3.8/site-packages/pyitlib/discrete_random_variable.py", line 4759, in _verify_alphabet_sufficiently_large
#     assert(not np.any(X == np.array(None)))
#   File "/mnt/data/yiwei/GeneticAlgorithm/Scorer.py", line 48, in Score
#     score = ScoreSelectNodesFromAdjMatrix( matrix, nodes_to_score, self.regular_factor, self.columns, self.alpha )
#   File "/home/yiwei/.local/lib/python3.8/site-packages/pyitlib/discrete_random_variable.py", line 3685, in entropy_joint
#     X = X[:, X[i].argsort(kind='mergesort')]
#   File "/home/yiwei/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py", line 86, in _wrapreduction
#     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#   File "/home/yiwei/.local/lib/python3.8/site-packages/pyitlib/discrete_random_variable.py", line 3671, in entropy_joint
#     S, fill_value = _map_observations_to_integers((X, Alphabet_X),
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/_label.py", line 101, in fit
#     self.classes_ = _unique(y)
#   File "/home/yiwei/.local/lib/python3.8/site-packages/pyitlib/discrete_random_variable.py", line 3671, in entropy_joint
#     S, fill_value = _map_observations_to_integers((X, Alphabet_X),
#   File "/home/yiwei/.local/lib/python3.8/site-packages/pyitlib/discrete_random_variable.py", line 4687, in _map_observations_to_integers
#     Symbol_matrices = [L.transform(A.ravel()).reshape(A.shape) for A in
#   File "/mnt/data/yiwei/GeneticAlgorithm/Scorer.py", line 70, in ScoreSelectNodesFromAdjMatrix
#     score = - ( drv.entropy_joint( parents_and_node, fill_value = -999 ) - drv.entropy_joint( parents, fill_value = -999 ) )
# KeyboardInterrupt
# KeyboardInterrupt
#   File "<__array_function__ internals>", line 180, in unique
#   File "/mnt/data/yiwei/GeneticAlgorithm/Scorer.py", line 70, in ScoreSelectNodesFromAdjMatrix
#     score = - ( drv.entropy_joint( parents_and_node, fill_value = -999 ) - drv.entropy_joint( parents, fill_value = -999 ) )
# KeyboardInterrupt
#   File "/home/yiwei/.local/lib/python3.8/site-packages/pyitlib/discrete_random_variable.py", line 3685, in entropy_joint
#     X = X[:, X[i].argsort(kind='mergesort')]
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/mnt/data/yiwei/GeneticAlgorithm/Scorer.py", line 70, in ScoreSelectNodesFromAdjMatrix
#     score = - ( drv.entropy_joint( parents_and_node, fill_value = -999 ) - drv.entropy_joint( parents, fill_value = -999 ) )
#   File "/home/yiwei/.local/lib/python3.8/site-packages/pyitlib/discrete_random_variable.py", line 4685, in _map_observations_to_integers
#     L.fit(np.concatenate([A.ravel() for A in Symbol_matrices] + F))
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/utils/_encode.py", line 33, in _unique
#     out = np.unique(values, return_inverse=return_inverse)
#   File "/home/yiwei/.local/lib/python3.8/site-packages/pyitlib/discrete_random_variable.py", line 4693, in _map_observations_to_integers
#     A[A == f] = FILL_VALUE
#   File "/home/yiwei/.local/lib/python3.8/site-packages/pyitlib/discrete_random_variable.py", line 4687, in <listcomp>
#     Symbol_matrices = [L.transform(A.ravel()).reshape(A.shape) for A in
#   File "/home/yiwei/.local/lib/python3.8/site-packages/pyitlib/discrete_random_variable.py", line 3685, in entropy_joint
#     X = X[:, X[i].argsort(kind='mergesort')]
#   File "/home/yiwei/.local/lib/python3.8/site-packages/pyitlib/discrete_random_variable.py", line 3646, in entropy_joint
#     X, fill_value_X = _sanitise_array_input(X, fill_value)
#   File "/home/yiwei/.local/lib/python3.8/site-packages/numpy/lib/arraysetops.py", line 272, in unique
#     ret = _unique1d(ar, return_index, return_inverse, return_counts)
# KeyboardInterrupt
#   File "/home/yiwei/.local/lib/python3.8/site-packages/pyitlib/discrete_random_variable.py", line 3646, in entropy_joint
#     X, fill_value_X = _sanitise_array_input(X, fill_value)
# KeyboardInterrupt
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/_label.py", line 138, in transform
#     return _encode(y, uniques=self.classes_)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/_label.py", line 101, in fit
#     self.classes_ = _unique(y)
#   File "<__array_function__ internals>", line 180, in unique
# KeyboardInterrupt
#   File "/home/yiwei/.local/lib/python3.8/site-packages/numpy/lib/arraysetops.py", line 333, in _unique1d
#     ar.sort()
#   File "/home/yiwei/.local/lib/python3.8/site-packages/pyitlib/discrete_random_variable.py", line 4709, in _sanitise_array_input
#     if np.any(np.equal(X, None)) or fill_value is None:
#   File "/home/yiwei/.local/lib/python3.8/site-packages/pyitlib/discrete_random_variable.py", line 4709, in _sanitise_array_input
#     if np.any(np.equal(X, None)) or fill_value is None:
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/utils/_encode.py", line 33, in _unique
#     out = np.unique(values, return_inverse=return_inverse)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/utils/_encode.py", line 183, in _encode
#     diff = _check_unknown(values, uniques)
#   File "/home/yiwei/.local/lib/python3.8/site-packages/numpy/lib/arraysetops.py", line 272, in unique
#     ret = _unique1d(ar, return_index, return_inverse, return_counts)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/utils/_encode.py", line 245, in _check_unknown
#     unique_values = np.unique(values)
#   File "<__array_function__ internals>", line 180, in unique
#   File "/home/yiwei/.local/lib/python3.8/site-packages/numpy/lib/arraysetops.py", line 325, in _unique1d
#     ar = np.asanyarray(ar).flatten()
#   File "<__array_function__ internals>", line 180, in unique
#   File "/home/yiwei/.local/lib/python3.8/site-packages/numpy/lib/arraysetops.py", line 272, in unique
#     ret = _unique1d(ar, return_index, return_inverse, return_counts)
# KeyboardInterrupt
#   File "/home/yiwei/.local/lib/python3.8/site-packages/numpy/lib/arraysetops.py", line 272, in unique
#     ret = _unique1d(ar, return_index, return_inverse, return_counts)
#   File "/home/yiwei/.local/lib/python3.8/site-packages/numpy/lib/arraysetops.py", line 333, in _unique1d
#     ar.sort()
#   File "/home/yiwei/.local/lib/python3.8/site-packages/numpy/lib/arraysetops.py", line 325, in _unique1d
#     ar = np.asanyarray(ar).flatten()
# KeyboardInterrupt
# KeyboardInterrupt
